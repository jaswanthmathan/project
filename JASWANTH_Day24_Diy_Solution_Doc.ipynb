# %% [markdown]
# <a href="https://colab.research.google.com/github/jaswanthmathan/project/blob/main/JASWANTH_Day24_Diy_Solution_Doc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1. Problem Statement: Conditional Probability
# Load the “kerala.csv” data into a DataFrame and perform the following tasks:
# 1. Explore the DataFrame using info() and describe() functions
# 2. June and July are the peak months of rainfall. Consider that if it rains more
# than 500mm, then the chances of flood become more; create a Datarame
# with columns –“YEAR”, “JUN_GT_500” (Contains a boolean value to show
# whether it rained more than 500 mm in June), “JUL_GT_500” (Contains a
# boolean value to show whether it rained more than 500 mm in July), and
# “FLOODS” (Contains a boolean value to show whether it flooded that year)
# 3. Calculate the probability of flood given it rained more than 500 mm in June
# (P(A|B))
# 4. Calculate the probability of rain more than 500 mm in June, given it flooded
# that year (P(B|A))
# 5. Probability of flood given it rained more than 500 mm in July
# 6. Probability of rain of more than 500 mm in July given it flooded that year
# (P(B|A))

# %%
import pandas as pd

# Load the data into a DataFrame
df = pd.read_csv('kerala.csv')
df
# Out:
#     SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL     AUG  \
# 0        KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0   357.5
# 1        KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0   315.8
# 2        KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5   420.2
# 3        KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5   351.8
# 4        KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5   293.6
# ..          ...   ...   ...   ...   ...    ...    ...     ...     ...     ...
# 113      KERALA  2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8   733.9
# 114      KERALA  2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0   252.2
# 115      KERALA  2016   2.4   3.8  35.9  143.0  186.4   522.2   412.3   325.5
# 116     KERALA   2017   1.9   6.8   8.9   43.6  173.5   498.5   319.6   531.8
# 117      KERALA  2018  29.1  52.1  48.6  116.4  183.8   625.4  1048.5  1398.9
#
# ...

# %%
print(df.describe())
# Out:
#               YEAR         JAN         FEB         MAR         APR  \
# count   118.000000  118.000000  118.000000  118.000000  118.000000
# mean   1959.500000   12.218644   15.633898   36.670339  110.330508
# std      34.207699   15.473766   16.406290   30.063862   44.633452
# min    1901.000000    0.000000    0.000000    0.100000   13.100000
# 25%    1930.250000    2.175000    4.700000   18.100000   74.350000
# 50%    1959.500000    5.800000    8.350000   28.400000  110.400000
# 75%    1988.750000   18.175000   21.400000   49.825000  136.450000
# max    2018.000000   83.500000   79.000000  217.200000  238.000000
#
#               MAY          JUN          JUL          AUG         SEP  \
# count  118.000000   118.000000   118.000000   118.000000  118.000000
# mean   228.644915   651.617797   698.220339   430.369492  246.207627
# std    147.548778   186.181363   228.988966   181.980463  121.901131
# min     53.400000   196.800000   167.500000   178.600000   41.300000
# ...

# %%
df["FLOODS"].value_counts()
# Out:
# YES    60
# NO     58
# Name: FLOODS, dtype: int64

# %%
df["FLOODS"]=df["FLOODS"].map({'YES':1,'NO':0})
df.head()
# Out:
#   SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL    AUG  \
# 0      KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0  357.5
# 1      KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0  315.8
# 2      KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5  420.2
# 3      KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5  351.8
# 4      KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5  293.6
#
#      SEP    OCT    NOV    DEC   ANNUAL RAINFALL  FLOODS
# 0  197.7  266.9  350.8   48.4            3248.6       1
# 1  491.6  358.4  158.3  121.5            3326.6       1
# 2  341.8  354.1  157.0   59.0            3271.2       1
# 3  222.7  328.1   33.9    3.3            3129.7       1
# 4  217.2  383.5   74.4    0.2            2741.6       0

# %%
df["JUN_GT_500"]=(df['JUN']>500).astype("int")
df["JUL_GT_500"]=(df['JUL']>500).astype("int")
df_small=df.loc[:,["YEAR","JUN_GT_500","FLOODS"]]
df_small["COUNT"]=1
df_small.head()
# Out:
#    YEAR  JUN_GT_500  FLOODS  COUNT
# 0  1901           1       1      1
# 1  1902           0       1      1
# 2  1903           1       1      1
# 3  1904           1       1      1
# 4  1905           1       0      1

# %%
pd.crosstab(df_small["FLOODS"],df_small["JUN_GT_500"])
# Out:
# JUN_GT_500   0   1
# FLOODS
# 0           19  39
# 1            6  54

# %%
P_F=(6+54)/(6+54+19+39)
P_J=(39+57)/(3+57+19+39)
P_F_intersect_J=57/(3+57+19+39)
print(f"P(FLOOD):{P_F}")
print(f"P(June):{P_J}")
print(f"P(FLOOD AND JULY):{P_F_intersect_J}")
# Out:
# P(FLOOD):0.5084745762711864
# P(June):0.8135593220338984
# P(FLOOD AND JULY):0.4830508474576271

# %%
P_F_J=P_F_intersect_J/P_J
print("Probability of flood given it rained more than 500 mm in June(P(A|B)):")
print(f"P(FLOOD|JUNE): {P_F_J}")
# Out:
# Probability of flood given it rained more than 500 mm in June(P(A|B)):
# P(FLOOD|JUNE): 0.59375

# %%
P_J_F=(P_F_J*P_J)/P_F
print(" probability of rain more than 500 mm in June, given it flooded that year (P(B|A))")
print(f"P(FLOOD|JUNE): {P_F_J}")
# Out:
#  probability of rain more than 500 mm in June, given it flooded that year (P(B|A))
# P(FLOOD|JUNE): 0.59375

# %%
P_F_J=P_F_intersect_J/P_J
print("Probability of flood given it rained more than 500 mm in July:")
print(f"P(FLOOD|JULY):{P_F_J}")
# Out:
# Probability of flood given it rained more than 500 mm in July:
# P(FLOOD|JULY):0.59375

# %%
P_J_F=(P_F_J*P_J)/P_F
print("Probability of rain of more than 500 mm in July given it flooded that year (P(B|A)):")
print(f"P(JULY|FLOOD): {P_J_F}")
# Out:
# Probability of rain of more than 500 mm in July given it flooded that year (P(B|A)):
# P(JULY|FLOOD): 0.9500000000000002
